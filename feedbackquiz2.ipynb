# %% [markdown]
# ## <font color='red'><b>11.5/15<b></font>

# %% [markdown]
# ## 1 import packages
#
# <font color='red'><b>Correct.<b></font>

# %%
import matplotlib.pyplot
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## 2. set context of seaborn theme to poster
#
# <font color='red'><b>Incorrect. you should write a line of code<b></font>

# %% [markdown]
# the context of seaborn is a book

# %% [markdown]
# ### 3 load the diamonds dataset
#
# <font color='red'><b>Correct.<b></font>

# %%
dir(sns)
d=sns.load_dataset('diamonds')
d
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9       0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10      0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# ...

# %% [markdown]
# ## 4. how many columns in this dataset?
#
#
# <font color='red'><b>Correct.<b></font>

# %%
col=d.shape[1]
print('the dataset have', col, 'colums')
# Out:
# the dataset have 10 colums

# %% [markdown]
# ## 5. list the names of all columns
#
# <font color='red'><b>Correct.<b></font>

# %%
print(d.columns)
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %% [markdown]
# ## 5.1 describe the datatype of each column?

# %%
columns=d.columns
for i in columns:
    print(i, 'have type', d[i].dtype)
# Out:
# carat have type float64
# cut have type category
# color have type category
# clarity have type category
# depth have type float64
# table have type float64
# price have type int64
# x have type float64
# y have type float64
# z have type float64

# %% [markdown]
# ## 6. list the unique number of diamond colors in this dataset?
#
# <font color='red'><b>Correct.<b></font>

# %%
import numpy as np

# %%
np.unique(d.color)
# Out:
# array(['D', 'E', 'F', 'G', 'H', 'I', 'J'], dtype=object)

# %% [markdown]
# ## 7. what is the minimum depth of diamond?
#
# <font color='red'><b>Correct.<b></font>

# %%
print('the minimum depth of diamond is ', d['depth'].min())
# Out:
# the minimum depth of diamond is  43.0

# %% [markdown]
# ## 8. count the diamonds by their clarity and cut
#
# <font color='red'><b>Correct.<b></font>

# %%
d.groupby(['clarity','cut']).count()
# Out:
#                    carat  color  depth  table  price     x     y     z
# clarity cut
# IF      Ideal       1212   1212   1212   1212   1212  1212  1212  1212
#         Premium      230    230    230    230    230   230   230   230
#         Very Good    268    268    268    268    268   268   268   268
#         Good          71     71     71     71     71    71    71    71
#         Fair           9      9      9      9      9     9     9     9
# VVS1    Ideal       2047   2047   2047   2047   2047  2047  2047  2047
#         Premium      616    616    616    616    616   616   616   616
#         Very Good    789    789    789    789    789   789   789   789
#         Good         186    186    186    186    186   186   186   186
#         Fair          17     17     17     17     17    17    17    17
# VVS2    Ideal       2606   2606   2606   2606   2606  2606  2606  2606
#         Premium      870    870    870    870    870   870   870   870
# ...

# %% [markdown]
# ## 9. list the color, clarity, and prices of the most expensive diamond?
#
# <font color='red'><b>Correct but you should not print extra info .<b></font>

# %%
d['price'].max()
# Out:
# 18823

# %%
d[d['price']==18823]
# Out:
#        carat      cut color clarity  depth  table  price    x     y     z
# 27749   2.29  Premium     I     VS2   60.8   60.0  18823  8.5  8.47  5.16

# %%
print('the most expensive diamonds have color I, clarity VS2 and his price is 18823')
# Out:
# the most expensive diamonds have color I, clarity VS2 and his price is 18823

# %% [markdown]
# ## 10. produce the following figures
#
# <font color='red'><b>Correct.<b></font>

# %%
d.dropna
# Out:
# <bound method DataFrame.dropna of        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# ...

# %%
sns.scatterplot(x='x', y='price', data=d, hue='cut')
# Out:
# <AxesSubplot:xlabel='x', ylabel='price'>

# %% [markdown]
# <font color='red'><b>Use violin plot, please.<b></font>

# %%
sns.boxplot(x='cut', y='price', data=d)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %% [markdown]
# ## build a regression model using carat, depth, x, y, and z columns as explana-tory variables and price column as response variable, and report its accuracy using mean squared error metric?

# %%
import pandas as pd
import numpy as np
import os ,sys, warnings
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import datasets,linear_model
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <font color='red'><b>You have asked to train using LinearRegression model not Rdge, also for accuracy you have to use mean squared error metric (with y_test and y_pred)<b></font>

# %%
# extracting explanatory and response variables
X = d[['carat', 'depth', 'x', 'y','z']].values.reshape(-1, 5)   
y = d['price'].values.reshape(-1,1)
# Split the targets into training/testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
# Create linear regression with L2/L1 penalty term
regr = linear_model.Ridge(alpha = 0.5)
# Train the model using the training sets
regr.fit(X_train, y_train)
# Make predictions using the testing set
y_pred = regr.predict(X_test)

# %%
accuracy_score(y_train, y_pred, normalize=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-f847719de76c> in <module>
# ----> 1 accuracy_score(y_train, y_pred, normalize=False)
#
# /usr/lib/python3/dist-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /usr/lib/python3/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     185
#     186     # Compute accuracy for each possible representation
# --> 187     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     188     check_consistent_length(y_true, y_pred, sample_weight)
#     189     if y_type.startswith('multilabel'):
#
# ...
